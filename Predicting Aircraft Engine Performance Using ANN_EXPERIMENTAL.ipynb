# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pytorch_lightning as pl
import torch.optim as optim
import torch.utils.data as data
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from numpy import exp, sum, log, log10

# %%
# Define a custom dataset class
class AircraftDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
def get_data(io='Tabulated flight data.xlsx', sheet_name=0):
    return pd.read_excel(io, sheet_name)

path= 'Tabulated flight data.xlsx'
X_data= 'X'
y_data='y'

# Getting Data
allX=get_data(path, sheet_name=X_data)
ally=get_data(path, sheet_name=y_data)

# %%
allX
# Out:
#        Airspeed (Knots)(TAS)  Altitude (FT)(ALT)  Temperature (DEG)(TAT)  \
# 0                        0.0                 -17                   14.50
# 1                        0.0                 -17                   14.50
# 2                        0.0                 -18                   14.50
# 3                        0.0                 -18                   14.50
# 4                        0.0                 -18                   14.75
# ...                      ...                 ...                     ...
# 22879                    0.0                 867                   26.25
# 22880                    0.0                 867                   26.25
# 22881                    0.0                 866                   26.25
# 22882                    0.0                 866                   26.00
# 22883                    0.0                 866                   26.00
#
#        Exhaust Temperature (DEG)(EGT)  Mach Number(MACH)(MACH)
# 0                              24.750                      0.0
# 1                              24.750                      0.0
# 2                              24.750                      0.0
# 3                              24.625                      0.0
# 4                              24.625                      0.0
# ...                               ...                      ...
# 22879                         240.500                      0.0
# 22880                         239.875                      0.0
# 22881                         239.125                      0.0
# 22882                         238.500                      0.0
# 22883                         238.125                      0.0
#
# [22884 rows x 5 columns]

# %%
ally
# Out:
#        Thrust (%RPM)(N1)  Ground Speed (Knots)(GS)  Fuel Consumption (LBS/HR)
# 0               1.625000                       0.0                          0
# 1               1.625000                       0.0                          0
# 2               1.625000                       0.0                          0
# 3               1.625000                       0.0                          0
# 4               1.625000                       0.0                          0
# ...                  ...                       ...                        ...
# 22879           1.625000                       0.0                          0
# 22880           1.625000                       0.0                          0
# 22881           1.625000                       0.0                          0
# 22882           1.625000                       0.0                          0
# 22883           1.617188                       0.0                          0
#
# [22884 rows x 3 columns]

# %%
class PerformancePredictionModel(pl.LightningModule):
    def __init__(self, input_size= 5, hidden_size = 64, output_size=3, dropout_rate=0.2):
        super().__init__()
        self.criterion = nn.MSELoss()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_rate)
        self.relu = nn.LeakyReLU()

    def forward(self, x):
        x = torch.relu(x)
        x = self.flatten(x)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.dropout(self.relu(self.fc2(x)))
        x = self.fc3(x)
        return x
        
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat, y)
        self.log('train_loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat, y)
        self.log('val_loss', loss)
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat, y)
        self.log('test_loss', loss)
        return loss
        
    def configure_optimizers(self):
        # Use Adam optimizer for LM and BR
        return optim.Adam(self.parameters(), lr=0.01)
    
    def lm_train(self, train_loader, max_epochs=100):
        optimizer = torch.optim.LBFGS(self.parameters(), lr=0.001)  # Levenberg-Marquardt optimizer
        
        def closure():
            optimizer.zero_grad()
            predictions = self.forward(x)
            loss = self.criterion(predictions, y)
            loss.backward()
            return loss
        
        for epoch in range(max_epochs):
            self.train()
            for x, y in train_loader:
                optimizer.step(closure)
    
    def br_train(self, train_loader, max_epochs=100):
        optimizer = torch.optim.RMSprop(self.parameters(), lr=0.001, alpha=0.99)  # Bayesian regularization optimizer
        
        for epoch in range(max_epochs):
            self.train()
            for x, y in train_loader:
                predictions = self.forward(x)
                loss = self.criterion(predictions, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

# %%
class DatasetModule(pl.LightningDataModule):
    def __init__(self, allX, ally):
        super().__init__()
        self.allX = allX
        self.ally = ally

        self.allX = self.allX.to_numpy().astype(np.float32)
        self.ally = self.ally.to_numpy().astype(np.float32)

        # Normalize data
        #self.scaler_X = StandardScaler().fit(self.allX)
        #self.allX = self.scaler_X.transform(self.allX)
        #self.scaler_y = StandardScaler().fit(self.ally)
        #self.ally = self.scaler_y.transform(self.ally)

        # Split data into training and validation sets
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.allX, self.ally, test_size=0.2, random_state=42)
        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(self.X_train, self.y_train, test_size=0.25, random_state=42)

        self.scaler_X_train = MinMaxScaler().fit(self.X_train)
        self.X_train = self.scaler_X_train.transform(self.X_train)
        self.scaler_y_train = MinMaxScaler().fit(self.y_train)
        self.y_train = self.scaler_y_train.transform(self.y_train)
        
        self.scaler_X_test = MinMaxScaler().fit(self.X_test)
        self.X_test = self.scaler_X_test.transform(self.X_test)
        self.scaler_y_test = MinMaxScaler().fit(self.y_test)
        self.y_test = self.scaler_y_test.transform(self.y_test)
        
        self.scaler_X_val = MinMaxScaler().fit(self.X_val)
        self.X_val = self.scaler_X_val.transform(self.X_val)
        self.scaler_y_val = MinMaxScaler().fit(self.y_val)
        self.y_val = self.scaler_y_val.transform(self.y_val)

        self.train_set = AircraftDataset(self.X_train, self.y_train)
        self.valid_set = AircraftDataset(self.X_val, self.y_val)
        self.test_set = AircraftDataset(self.X_test, self.y_test)
        self.batch_size = 200  # batch size roughly 1/100th of large dataset

    def train_dataloader(self):
        train_dataloader = DataLoader(self.train_set, batch_size=self.batch_size, shuffle=True, num_workers=0) 
        return train_dataloader

    def val_dataloader(self):
        val_dataloader = DataLoader(self.valid_set, batch_size=self.batch_size, shuffle=False, num_workers=0)
        return val_dataloader

    def test_dataloader(self):
        test_dataloader = DataLoader(self.test_set, batch_size=self.batch_size, shuffle=False, num_workers=0)
        return test_dataloader

# %%
import warnings
warnings.filterwarnings("ignore", ".*does not have many workers.*")

# %% [markdown]
# ### Testing with only adam optimizer

# %%
input_size = 5  # Airspeed, _Altitude, Air Temp, Exhaust Temp, Cruise Mach Number
hidden_size = 128
output_size = 3 # Thrust, Ground Speed, Fuel Consumption
dropout_rate = 0.2

# %%
# Create DatasetModule instance
DatasetM = DatasetModule(allX, ally)

# %%
# Initialize the model
model = PerformancePredictionModel(input_size=input_size, hidden_size = hidden_size, output_size=output_size, dropout_rate=dropout_rate)

# Initialize a trainer
trainer = pl.Trainer(devices="auto", accelerator="auto", log_every_n_steps= 1, max_epochs=100, enable_progress_bar=False)

# Train the model
trainer.fit(model, DatasetM)

# Get MSE of Training Sets
train_loss = trainer.callback_metrics['train_loss'].item()
print(f'Training MSE: {train_loss}')

# Get MSE of Validation Set
val_loss = trainer.callback_metrics['val_loss'].item()
print(f'Validation MSE: {val_loss}')

# Test the model
trainer.test(model, dataloaders=DatasetM)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 768
# 3 | fc2       | Linear    | 16.5 K
# 4 | fc3       | Linear    | 387
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 17.7 K    Trainable params
# 0         Non-trainable params
# 17.7 K    Total params
# 0.071     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Training MSE: 0.0017307059606537223
# Validation MSE: 0.0010246665915474296
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │   0.000944719125982374    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.000944719125982374}]

# %%
# Create DatasetModule instance
DatasetM = DatasetModule(allX, ally)

# Initialize the model
model = PerformancePredictionModel(input_size=input_size, hidden_size = hidden_size, output_size=output_size, dropout_rate=dropout_rate)

# Initialize a trainer
trainer = pl.Trainer(devices="auto", accelerator="auto", log_every_n_steps= 1, max_epochs=100, enable_progress_bar=False)

# Train with Levenberg-Marquardt optimizer
train_loader = DatasetM.train_dataloader()
model.lm_train(train_loader, max_epochs=100)

# Train the model
trainer.fit(model, DatasetM)

# Get MSE of Training Sets
train_loss = trainer.callback_metrics['train_loss'].item()
print(f'Training MSE: {train_loss}')

# Get MSE of Validation Set
val_loss = trainer.callback_metrics['val_loss'].item()
print(f'Validation MSE: {val_loss}')

# Test the model
trainer.test(model, dataloaders=DatasetM)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 768
# 3 | fc2       | Linear    | 16.5 K
# 4 | fc3       | Linear    | 387
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 17.7 K    Trainable params
# 0         Non-trainable params
# 17.7 K    Total params
# 0.071     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Training MSE: 0.001132642268203199
# Validation MSE: 0.001031257095746696
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │   0.0009905369952321053   │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.0009905369952321053}]

# %%
# Create DatasetModule instance
DatasetM = DatasetModule(allX, ally)

# Initialize the model
model = PerformancePredictionModel(input_size=input_size, hidden_size = hidden_size, output_size=output_size, dropout_rate=dropout_rate)

# Initialize a trainer
trainer = pl.Trainer(devices="auto", accelerator="auto", log_every_n_steps= 1, max_epochs=100, enable_progress_bar=False)

# Train with Bayesian regularization optimizer
train_loader = DatasetM.train_dataloader()
model.br_train(train_loader, max_epochs=100)

# Train the model
trainer.fit(model, DatasetM)

# Get MSE of Training Sets
train_loss = trainer.callback_metrics['train_loss'].item()
print(f'Training MSE: {train_loss}')

# Get MSE of Validation Set
val_loss = trainer.callback_metrics['val_loss'].item()
print(f'Validation MSE: {val_loss}')

# Test the model
trainer.test(model, dataloaders=DatasetM)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 768
# 3 | fc2       | Linear    | 16.5 K
# 4 | fc3       | Linear    | 387
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 17.7 K    Trainable params
# 0         Non-trainable params
# 17.7 K    Total params
# 0.071     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Training MSE: 0.0014377435436472297
# Validation MSE: 0.0007794809644110501
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │   0.0007170778117142618   │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.0007170778117142618}]

# %%
import optuna

# %%
def objective(trial):
    hidden_size = trial.suggest_int('hidden_size', 16, 256)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 1)

    # Initialize the model with optimized hyperparameters
    model = PerformancePredictionModel(hidden_size=hidden_size, dropout_rate=dropout_rate)

    # Initialize a trainer
    trainer = pl.Trainer(devices="auto", accelerator="auto", log_every_n_steps= 1, max_epochs=50, enable_progress_bar=False)
    
    # Train with Bayesian regularization optimizer
    train_loader = DatasetM.train_dataloader()
    model.br_train(train_loader, max_epochs=10)
    
    # Train the model
    trainer.fit(model, DatasetM)

    # Return validation loss for optimization
    return trainer.callback_metrics['val_loss'].item()

# Create DatasetModule instance
DatasetM = DatasetModule(allX, ally)

# Perform hyperparameter optimization
study = optuna.create_study()
study.optimize(objective, n_trials=20)
best_params = study.best_params
# Out:
# [I 2024-05-20 18:31:38,661] A new study created in memory with name: no-name-2fae3e51-23b1-42d1-802b-371d9d11fbbf
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 786
# 3 | fc2       | Linear    | 17.3 K
# 4 | fc3       | Linear    | 396
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 18.5 K    Trainable params
# 0         Non-trainable params
# 18.5 K    Total params
# 0.074     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:32:12,547] Trial 0 finished with value: 0.05289389565587044 and parameters: {'hidden_size': 131, 'dropout_rate': 0.9681616545244155}. Best is trial 0 with value: 0.05289389565587044.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 738
# 3 | fc2       | Linear    | 15.3 K
# 4 | fc3       | Linear    | 372
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 16.4 K    Trainable params
# 0         Non-trainable params
# 16.4 K    Total params
# 0.065     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:32:48,051] Trial 1 finished with value: 0.0009531962568871677 and parameters: {'hidden_size': 123, 'dropout_rate': 0.26831884627862435}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.5 K
# 3 | fc2       | Linear    | 64.3 K
# 4 | fc3       | Linear    | 762
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 66.5 K    Trainable params
# 0         Non-trainable params
# 66.5 K    Total params
# 0.266     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:33:26,504] Trial 2 finished with value: 0.010954303666949272 and parameters: {'hidden_size': 253, 'dropout_rate': 0.8771153780138303}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 426
# 3 | fc2       | Linear    | 5.1 K
# 4 | fc3       | Linear    | 216
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 5.8 K     Trainable params
# 0         Non-trainable params
# 5.8 K     Total params
# 0.023     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:33:58,516] Trial 3 finished with value: 0.0021282474044710398 and parameters: {'hidden_size': 71, 'dropout_rate': 0.5339293775692959}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 912
# 3 | fc2       | Linear    | 23.3 K
# 4 | fc3       | Linear    | 459
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 24.6 K    Trainable params
# 0         Non-trainable params
# 24.6 K    Total params
# 0.099     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:34:33,294] Trial 4 finished with value: 0.007102527189999819 and parameters: {'hidden_size': 152, 'dropout_rate': 0.8149430216397275}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 462
# 3 | fc2       | Linear    | 6.0 K
# 4 | fc3       | Linear    | 234
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 6.7 K     Trainable params
# 0         Non-trainable params
# 6.7 K     Total params
# 0.027     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:35:05,830] Trial 5 finished with value: 0.0014013322070240974 and parameters: {'hidden_size': 77, 'dropout_rate': 0.22651451441210652}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.1 K
# 3 | fc2       | Linear    | 35.2 K
# 4 | fc3       | Linear    | 564
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 36.8 K    Trainable params
# 0         Non-trainable params
# 36.8 K    Total params
# 0.147     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:35:41,411] Trial 6 finished with value: 0.0011213368270546198 and parameters: {'hidden_size': 187, 'dropout_rate': 0.1473774020622918}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 690
# 3 | fc2       | Linear    | 13.3 K
# 4 | fc3       | Linear    | 348
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 14.4 K    Trainable params
# 0         Non-trainable params
# 14.4 K    Total params
# 0.058     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:36:15,937] Trial 7 finished with value: 0.0015271538868546486 and parameters: {'hidden_size': 115, 'dropout_rate': 0.4666644780339383}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 156
# 3 | fc2       | Linear    | 702
# 4 | fc3       | Linear    | 81
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 939       Trainable params
# 0         Non-trainable params
# 939       Total params
# 0.004     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:36:44,900] Trial 8 finished with value: 0.006780578754842281 and parameters: {'hidden_size': 26, 'dropout_rate': 0.6750350009772839}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 378
# 3 | fc2       | Linear    | 4.0 K
# 4 | fc3       | Linear    | 192
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 4.6 K     Trainable params
# 0         Non-trainable params
# 4.6 K     Total params
# 0.018     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:37:16,287] Trial 9 finished with value: 0.0012466022744774818 and parameters: {'hidden_size': 63, 'dropout_rate': 0.22537933338664745}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.3 K
# 3 | fc2       | Linear    | 47.7 K
# 4 | fc3       | Linear    | 657
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 49.7 K    Trainable params
# 0         Non-trainable params
# 49.7 K    Total params
# 0.199     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:37:53,015] Trial 10 finished with value: 0.0013149966252967715 and parameters: {'hidden_size': 218, 'dropout_rate': 0.3580599671560033}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.1 K
# 3 | fc2       | Linear    | 34.8 K
# 4 | fc3       | Linear    | 561
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 36.5 K    Trainable params
# 0         Non-trainable params
# 36.5 K    Total params
# 0.146     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:38:27,716] Trial 11 finished with value: 0.0010150996968150139 and parameters: {'hidden_size': 186, 'dropout_rate': 0.10018263385545753}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.1 K
# 3 | fc2       | Linear    | 32.9 K
# 4 | fc3       | Linear    | 546
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 34.6 K    Trainable params
# 0         Non-trainable params
# 34.6 K    Total params
# 0.138     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:39:03,219] Trial 12 finished with value: 0.00117959373164922 and parameters: {'hidden_size': 181, 'dropout_rate': 0.35671436111196203}. Best is trial 1 with value: 0.0009531962568871677.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.0 K
# 3 | fc2       | Linear    | 28.1 K
# 4 | fc3       | Linear    | 504
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 29.6 K    Trainable params
# 0         Non-trainable params
# 29.6 K    Total params
# 0.118     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:39:38,193] Trial 13 finished with value: 0.0007277033873833716 and parameters: {'hidden_size': 167, 'dropout_rate': 0.1472998155164285}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 618
# 3 | fc2       | Linear    | 10.7 K
# 4 | fc3       | Linear    | 312
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 11.6 K    Trainable params
# 0         Non-trainable params
# 11.6 K    Total params
# 0.047     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:40:11,700] Trial 14 finished with value: 0.0014706871006637812 and parameters: {'hidden_size': 103, 'dropout_rate': 0.3922072098290375}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 942
# 3 | fc2       | Linear    | 24.8 K
# 4 | fc3       | Linear    | 474
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 26.2 K    Trainable params
# 0         Non-trainable params
# 26.2 K    Total params
# 0.105     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:40:48,919] Trial 15 finished with value: 0.001214365242049098 and parameters: {'hidden_size': 157, 'dropout_rate': 0.25853653448093905}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.3 K
# 3 | fc2       | Linear    | 48.6 K
# 4 | fc3       | Linear    | 663
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 50.6 K    Trainable params
# 0         Non-trainable params
# 50.6 K    Total params
# 0.202     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:41:25,201] Trial 16 finished with value: 0.003276160219684243 and parameters: {'hidden_size': 220, 'dropout_rate': 0.6746272229013852}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 612
# 3 | fc2       | Linear    | 10.5 K
# 4 | fc3       | Linear    | 309
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 11.4 K    Trainable params
# 0         Non-trainable params
# 11.4 K    Total params
# 0.046     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:41:58,516] Trial 17 finished with value: 0.0011578926350921392 and parameters: {'hidden_size': 102, 'dropout_rate': 0.301956119348872}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 924
# 3 | fc2       | Linear    | 23.9 K
# 4 | fc3       | Linear    | 465
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 25.3 K    Trainable params
# 0         Non-trainable params
# 25.3 K    Total params
# 0.101     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:42:35,356] Trial 18 finished with value: 0.0008623452740721405 and parameters: {'hidden_size': 154, 'dropout_rate': 0.17254931644399155}. Best is trial 13 with value: 0.0007277033873833716.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 972
# 3 | fc2       | Linear    | 26.4 K
# 4 | fc3       | Linear    | 489
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 27.9 K    Trainable params
# 0         Non-trainable params
# 27.9 K    Total params
# 0.111     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-05-20 18:43:11,196] Trial 19 finished with value: 0.0008931004558689892 and parameters: {'hidden_size': 162, 'dropout_rate': 0.15782228364425518}. Best is trial 13 with value: 0.0007277033873833716.

# %%
# Initialize the best model with the optimized hyperparameters
best_model = PerformancePredictionModel(hidden_size=best_params['hidden_size'], dropout_rate=best_params['dropout_rate'])

# Initialize a trainer
trainer = pl.Trainer(devices="auto", accelerator="auto", log_every_n_steps= 1, max_epochs=100, enable_progress_bar=False)

# Train with Bayesian regularization optimizer
train_loader = DatasetM.train_dataloader()
best_model.br_train(train_loader, max_epochs=100)

# Train the model
trainer.fit(best_model, DatasetM)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type      | Params
# ----------------------------------------
# 0 | criterion | MSELoss   | 0
# 1 | flatten   | Flatten   | 0
# 2 | fc1       | Linear    | 1.0 K
# 3 | fc2       | Linear    | 28.1 K
# 4 | fc3       | Linear    | 504
# 5 | dropout   | Dropout   | 0
# 6 | relu      | LeakyReLU | 0
# ----------------------------------------
# 29.6 K    Trainable params
# 0         Non-trainable params
# 29.6 K    Total params
# 0.118     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
# Get MSE of Training Set
train_loss = trainer.callback_metrics['train_loss'].item()
print(f'Training MSE: {train_loss}')

# Get MSE of Validation Set
val_loss = trainer.callback_metrics['val_loss'].item()
print(f'Validation MSE: {val_loss}')

# Test the model
trainer.test(best_model, dataloaders=DatasetM)
# Out:
# Training MSE: 0.0014634444378316402
# Validation MSE: 0.0007065354147925973
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │   0.0006854256498627365   │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.0006854256498627365}]
